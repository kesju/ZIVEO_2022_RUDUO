# %%
# TF modelio atkūrimas iš išsaugoto modelio diske

# https://medium.com/deep-learning-with-keras/save-load-keras-models-with-custom-layers-8f55ba9183d2

import tensorflow as tf
from pathlib import Path


# Nuoroda į modelio aplanką
# model_dir = Path(Duomenu_aplankas, 'DNN', 'best_models', 'all_ft')
model_dir = 'model_cnn_fda_vu_v0'
print("Modelio ir scaler parametrai nuskaitomas iš aplanko: ", model_dir)

model_path = Path(model_dir, 'best_model_final_2.h5')
model = tf.keras.models.load_model(model_path)

model.summary()
tf.keras.utils.plot_model(model,show_shapes=True)
# Out:
# Modelio ir scaler parametrai nuskaitomas iš aplanko:  model_cnn_fda_vu_v0
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (None, 218, 208)          1456
#
#  batch_normalization_1 (Batc  (None, 218, 208)         832
#  hNormalization)
#
#  activation_1 (Activation)   (None, 218, 208)          0
#
#  conv1d_2 (Conv1D)           (None, 218, 16)           13328
#
#  batch_normalization_2 (Batc  (None, 218, 16)          64
#  hNormalization)
#
#  activation_2 (Activation)   (None, 218, 16)           0
#
#  conv1d_3 (Conv1D)           (None, 218, 208)          36816
#
#  batch_normalization_3 (Batc  (None, 218, 208)         832
#  hNormalization)
#
#  activation_3 (Activation)   (None, 218, 208)          0
#
#  conv1d_4 (Conv1D)           (None, 218, 336)          769104
#
#  batch_normalization_4 (Batc  (None, 218, 336)         1344
#  hNormalization)
#
#  activation_4 (Activation)   (None, 218, 336)          0
#
#  conv1d_5 (Conv1D)           (None, 218, 464)          1559504
#
#  batch_normalization_5 (Batc  (None, 218, 464)         1856
#  hNormalization)
#
#  activation_5 (Activation)   (None, 218, 464)          0
#
#  conv1d_6 (Conv1D)           (None, 218, 336)          1091664
#
#  batch_normalization_6 (Batc  (None, 218, 336)         1344
#  hNormalization)
#
#  activation_6 (Activation)   (None, 218, 336)          0
#
#  conv1d_7 (Conv1D)           (None, 218, 272)          1005584
#
#  batch_normalization_7 (Batc  (None, 218, 272)         1088
#  hNormalization)
#
#  activation_7 (Activation)   (None, 218, 272)          0
#
#  conv1d_8 (Conv1D)           (None, 218, 272)          740112
#
#  batch_normalization_8 (Batc  (None, 218, 272)         1088
#  hNormalization)
#
#  activation_8 (Activation)   (None, 218, 272)          0
#
#  conv1d_9 (Conv1D)           (None, 218, 528)          1293072
#
#  batch_normalization_9 (Batc  (None, 218, 528)         2112
#  hNormalization)
#
#  activation_9 (Activation)   (None, 218, 528)          0
#
#  conv1d_10 (Conv1D)          (None, 218, 144)          304272
#
#  batch_normalization_10 (Bat  (None, 218, 144)         576
#  chNormalization)
#
#  activation_10 (Activation)  (None, 218, 144)          0
#
#  conv1d_11 (Conv1D)          (None, 218, 848)          1099856
#
#  batch_normalization_11 (Bat  (None, 218, 848)         3392
#  chNormalization)
#
#  activation_11 (Activation)  (None, 218, 848)          0
#
#  conv1d_12 (Conv1D)          (None, 218, 464)          2754768
#
#  batch_normalization_12 (Bat  (None, 218, 464)         1856
#  chNormalization)
#
#  activation_12 (Activation)  (None, 218, 464)          0
#
#  dense_9 (Dense)             (None, 218, 16)           7440
#
#  dense_10 (Dense)            (None, 218, 912)          15504
#
#  dense_11 (Dense)            (None, 218, 976)          891088
#
#  dense_12 (Dense)            (None, 218, 208)          203216
#
#  dense_13 (Dense)            (None, 218, 400)          83600
#
#  dense_14 (Dense)            (None, 218, 272)          109072
#
#  dense_15 (Dense)            (None, 218, 848)          231504
#
#  dense_16 (Dense)            (None, 218, 144)          122256
#
#  global_average_pooling1d_1   (None, 144)              0
#  (GlobalAveragePooling1D)
#
#  dense_17 (Dense)            (None, 3)                 435
#
# =================================================================
# Total params: 12,350,035
# Trainable params: 12,341,843
# Non-trainable params: 8,192
# _________________________________________________________________
